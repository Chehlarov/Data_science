# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

# %% [markdown]
# # Power Plant Cost

# %%
pp_df = pd.read_csv("nuclear.csv", index_col=None)

# %%
pp_df.dtypes
# Out:
# Unnamed: 0      int64
# cost          float64
# date          float64
# t1              int64
# t2              int64
# cap             int64
# pr              int64
# ne              int64
# ct              int64
# bw              int64
# cum.n           int64
# pt              int64
# dtype: object

# %%
pp_df
# Out:
#     Unnamed: 0    cost   date  t1  t2   cap  pr  ne  ct  bw  cum.n  pt
# 0            1  460.05  68.58  14  46   687   0   1   0   0     14   0
# 1            2  452.99  67.33  10  73  1065   0   0   1   0      1   0
# 2            3  443.22  67.33  10  85  1065   1   0   1   0      1   0
# 3            4  652.32  68.00  11  67  1065   0   1   1   0     12   0
# 4            5  642.23  68.00  11  78  1065   1   1   1   0     12   0
# 5            6  345.39  67.92  13  51   514   0   1   1   0      3   0
# 6            7  272.37  68.17  12  50   822   0   0   0   0      5   0
# 7            8  317.21  68.42  14  59   457   0   0   0   0      1   0
# 8            9  457.12  68.42  15  55   822   1   0   0   0      5   0
# 9           10  690.19  68.33  12  71   792   0   1   1   1      2   0
# 10          11  350.63  68.58  12  64   560   0   0   0   0      3   0
# 11          12  402.59  68.75  13  47   790   0   1   0   0      6   0
# ...

# %%
round(pp_df.cost.mean(), 2)
# Out:
# 461.56

# %%
pp_df["ne"].sum()
# Out:
# 8

# %%
tmp = pd.DataFrame({'y' : [1990], 'm': [1], 'd' : [1] })
tmp[['y', 'm', 'd']]
# qq = pd.to_datetime(tmp[['y', 'm', 'd']])
# Out:
#       y  m  d
# 0  1990  1  1

# %%
pd.to_datetime(1, unit='s')
# Out:
# Timestamp('1970-01-01 00:00:01')

# %%
pp_sorted = pp_df.sort_values(by='date')

# %%
plt.plot(pp_sorted.date, pp_sorted.cost)
plt.xlabel("years since 1990")
plt.ylabel("cost, M$")
plt.plot()
# Out:
# []

# %%
pp_df[pp_df.pr == 1].cap.max()
# Out:
# 1065
